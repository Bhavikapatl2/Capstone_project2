# %% [markdown]
# # **Project Name**    -Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -Bhavika Patel
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# Paisabazaar is one of India’s leading digital lending marketplaces, enabling customers to compare and apply for credit cards, personal loans, and other financial products.The company uses data checks, smart computer models, and manual verification to reduce fraud risk.Therefore, strong fraud detection systems are necessary to protect customers, lenders, and the platform itself and it verify the information given customers

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
#
# The goal of this project is to understand customer financial behavior, reduce risk, and prevent fraud. By analyzing data like income, loans, debt, and payment habits, Paisabazaar can identify high-risk customers, detect unusual patterns, and offer better loans to reliable customers. It also helps guide customers to manage their credit responsibly. Overall, the objective is to make smarter lending decisions, minimize losses, and support customers in improving their financial health.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data="/content/dataset.csv"
data1=pd.read_csv(data)
data1

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data1.head(5)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data1.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data1.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data1.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data1.isnull().sum()

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
# In this dataset there are 1000 rows and 28 columns.There are no null and duplicate values.There are 18 float ,3 integer and 7 object data types.The data describes  the name of person,age,id,occupation, any delayed payments,credit score,inhand salary,payment behaviour ,monthly balance,mode of emi etc.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data1.columns

# %%
# Dataset Describe
data1.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here.
#
# Age:
# Min: 14, Max: 56, Mean: 33, Median: 33
#
# Most customers are young to middle-aged.
#
# Annual Income
#
# Min: ₹81,490, Max: ₹9,999,934, Mean: ₹5,004,617, Median: ₹5,006,886
#
# Income distribution is wide, with many high-income customers.
#
# Monthly Inhand Salary
#
# Min: ₹7,005, Max: ₹1,79,987, Mean: ₹50,505, Median: ₹36,999
#
# Num_Bank_Accounts & Num_Credit_Card
#
# Avg accounts: 4, Avg cards: 5, Max: 11 each
#
# Customers have  multiple accounts and cards.
#
# Interest Rate
#
# Min: 1%, Max: 34%, Mean: 14.53%, Median: 13%
#
# Indicates more credit risk.
#
# Total EMI per Month
#
# Min: ₹0, Max: ₹1,779, Mean: ₹107, Median: ₹66
#
# Few customers  are paying very high EMIs.
#
# Credit Utilization Ratio
#
# Min: 20%, Max: 50%, Mean: 32%, Median: 32%
#
# Most customers use moderate credit levels.
#
# Delay from Due Date & Num of Delayed Payments
#
# Avg delay: 21 days, Avg delayed payments: 13
#
# Some customers frequently delay payments indicating failure risk.
#
# Credit History Age
#
# Min: 1 month, Max: 404 months, Mean: 221 months
#
# Many customers have long-standing credit histories .
#
# Monthly Balance & Amount Invested Monthly
#
# Avg balance: ₹392, Avg invested: ₹55
#
# Most maintain moderate savings, though some customers have very low balances.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data1.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
sns.barplot(data=data1,x="Interest_Rate",y="Annual_Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A bar plot shows the average value of Annual_Income for each Interest_Rate category.
#
# Interest_Rate acts like a category, while Annual_Income is numerical, which makes a bar plot suitable.
#
# Bars make it easy to visually compare income levels across different interest rates.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Shows if higher-income customers get lower/higher interest rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
#
# 1.Postive growth insights
#
# Yes, it can help create positive business impact.
#
# Reason:
# It helps the bank understand which income group is taking loans at certain interest rates.
# Using this information, companies like Paisabazaar can offer better loan plans to the right customers and increase profits.
# This helps the business attract more customers and earn more revenue.
#
# 2.Negative growth insights
#
# It can even create negative growth
#
# Reason:
# If low-income customers are paying very high interest rates, they may fail to repay loans.
# This can cause loan defaults and financial loss for the bank.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.countplot(data=data1, x="Credit_Score")
plt.title("Distribution of Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Countplot is used when the variable is categorical.
#
# It counts how many times each category appears in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# This plot shows how many customers fall into each credit score category (Good, Standard, Poor).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
#
# 1.Positive business impact
#
# Yes, this graph can help the business.
#
# Reason:
# It helps the bank see how many customers have good or bad credit scores.
# Companies like Paisabazaar can use this to approve loans for customers with good credit scores, which reduces risk.
#
# 2.Negative growth insights
#
# It also show problems.
#
# Reason:
# If the graph shows many customers with low credit scores it means there are higher chance of loan failure and greater financial risk for the bank

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.scatterplot(data=data1, x="Age", y="Annual_Income", hue="Credit_Score")
plt.title("Age vs Annual Income Colored by Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We use a scatter plot when we want to visualize the relationship between two numerical variables.
#
# Scatterplots helps in seeing how one variable changes with another

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# This plot shows how annual income changes with age.
#
# Coloring by Credit_Score helps see which age/income groups tend to have good, standard, or poor scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
#
# 1.Positive business impact
#
# Yes, it can help the business.
#
# Reason:
# The bank can see which age group has higher income and better credit scores.Companies like Paisabazaar can target those customers for loans, because they are more likely to repay.
#
# 2.Negative growth imapct
#
# Yes, it can show risk.
#
# Reason:
# If young or low-income customers have low credit scores, they may not repay loans, which can cause financial loss for the bank.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
sns.countplot(data=data1, x="Payment_of_Min_Amount")
plt.title("Payment of Minimum Amount Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We use a countplot for Payment_of_Min_Amount because this column is categorical, meaning it has categories like "Yes" or "No"and we want to see how many customers fall into each category.
#
# Each bar shows how many customers paid the minimum amount vs how many did not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Shows how many customers pay the minimum amount vs full payment.
#
# Customers who often pay only the minimum amount might be higher credit risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
#
# 1.Positive business impact
#
# Yes, it helps the business.
#
# Reason:
# If many customers pay the minimum amount on time it shows they are managing their credit properly.Companies like Paisabazaar can consider these customers more reliable for loans or credit cards.
#
# 2.Negative growth impact
#
# Yes, it can also show risk.
#
# Reason:
# If many customers do not pay the minimum amount, it means they may miss payments or failure on loans which can cause financial loss for the bank.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
sns.boxplot(data=data1, x="Credit_Score", y="Num_of_Loan")
plt.title("Number of Loans by Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We use a box plot in Seaborn to visualize the distribution of a numerical variable and detect outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Shows loan distribution for each credit score category.
#
# Highlights whether poor credit scores are associated with more loans.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive business impact
#
# Yes, it helps the business.
#
# Reason:
# If customers with good credit scores have more loans it means they are trusted customers who repay loans properly.Companies like Paisabazaar can give more loan offers to these customers.
#
# 2.Negative growth insight
#
# Yes, it can show risk.
#
# Reason:
# If customers with low credit scores have many loans, they may not be able to repay all loans, which can cause loan failure and loss for the bank.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.barplot(data=data1, x="Credit_Score", y="Total_EMI_per_month")
plt.title("Average EMI per Month by Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# People with Good credit scores usually have higher income and Banks approve larger loans for them hence having higher EMIs.
#
# Customers with Poor or Standard credit scores are often restricted to smaller loans and have EMIs lower and are riskier for banks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive business impact
#
# Yes, it can help the business.
#
# Reason:
# If customers with good credit scores pay higher EMI, it means they can manage bigger loans and repay on time.Companies like Paisabazaar can offer bigger loans to these reliable customers.
#
# 2.Negative growth insight
#
# Yes, it can show risk.
#
# Reason:
# If customers with low credit scores have very high EMI, they may struggle to pay every month, which can lead to loan failure and loss for the bank.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
sns.scatterplot(data=data1, x="Monthly_Inhand_Salary", y="Monthly_Balance", hue="Credit_Score")
plt.title("Salary vs Monthly Balance")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We use a scatter plot when we want to analyze the relationship between two numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Higher salary leads to higher remaining monthly balance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# shows the relationship between salary, remaining balance, and credit score.
#
# 1.Positive business impact
#
# Yes, it helps the business.
#
# Reason:
# If customers with higher salary and higher balance have good credit scores, they are more financially stable.Companies like Paisabazaar can offer loans or credit cards to these customers safely.
#
# 2.Negative growth insight
#
# Yes, it can show risk.
#
# Reason:
# If customers with low salary and low balance have poor credit scores, they may not repay loans on time which can cause financial loss for the bank.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.hist(data1["Credit_Utilization_Ratio"], bins=30, color="lightgreen", edgecolor="black")
plt.title("Distribution of Credit Utilization Ratio")
plt.xlabel("Credit Utilization Ratio")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# We have selected histplot because it is continous numerical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Shows how much of their credit customers are using.
#
# High utilization may indicate higher credit risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive business impact
#
# It helps identify customers with low credit utilization, meaning they use credit wisely these customers are less risky and can be targeted for loans or credit cards safely.
#
# 2.Negative growwth insight
#
# Customers with high credit utilization are using too much credit and may struggle to repay, which can lead to loan failure and losses.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
sns.countplot(data=data1, x="Num_Credit_Card")
plt.title("Number of Credit Cards per Customer")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We have selected the countplot because it helps to count no of customers having credit cards.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# It identifies customers with multiple credit cards, which can affect debt risk

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive business impact
#
# Customers with 1–2 credit cards are likely responsible with credit and  bank can offer them loans or other financial products safely, helping profit growth.
#
# 2.Negative growth insight
#
# Customers with many credit cards may overspend or struggle to repay leading to increase the risk of loan failure and financial loss.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
sns.boxplot(data=data1, x="Credit_Score", y="Monthly_Balance")
plt.title("Monthly Balance by Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# We have selected the boxplot to help indicate any outliers which unsually have low or high balances

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Customers with Good credit scores tend to maintain higher monthly balances, indicating financial stability.
#
# Customers with poor or standard credit score  might struggle to maintain higher balances, increasing the risk of defaults.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive Business impact
#
# It shows which credit score groups usually keep more money in their account so that Bank can offer special products (like loans or savings plans) to these groups  helping the business grow safely.
#
# 2.Negative growth insight
#
# If some people with low credit scores have high balances, they might suddenly withdraw or misuse money, which can cause risk for the bank.Low balances in high credit score groups can also mean less opportunity to earn from them.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
sns.barplot(data=data1, x="Payment_Behaviour", y="Credit_Utilization_Ratio")
plt.title("Average Credit Utilization by Payment Behaviour")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We have selected the barplot because it helps in disturbtion of categorical and numerical data.
#
# Each bar represents the mean credit utilization for a payment behaviour group.
#
# Helps quickly see which group uses more of their credit.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Customers who pay on time tend to use less of their available credit.
#
# Customers with poor payment behaviour have higher credit utilization, which means they are using most of their credit.
#
# Shows a clear link between payment habits and credit risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive business impact
#
# Customers who pay on time or in full usually have lower credit utilization.The bank can trust these customers more and offer loans or credit cards safely, helping business grow.
#
# 2.Negative growth insight
#
# Customers who miss payments or pay late often have high credit utilization and oftern risky for banks.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
data1['Payment_of_Min_Amount'].value_counts().plot.pie( figsize=(6,6), colors=['lightblue','lightgreen'])
plt.title("Payment of Minimum Amount Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# We use a pie chart for Payment_of_Min_Amount because it is a categorical variable and makes it easy to see what portion of customers pay only the minimum vs full payment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
#
# Most customers either pay the full amount or only the minimum amount.
#
# The chart shows the proportion of responsible vs less responsible payers.
#
# Customers who pay only the minimum may be at higher risk for defaults.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Positive business impact
#
# A large portion of customers paying the minimum amount shows they are responsible with payments.The bank can trust them for loans or credit cards, helping profit and growth.
#
# 2.Negative growth insight
#
# A big portion of customers not paying the minimum amount indicates risk of late payments or defaults lending to them could cause financial loss for the bank.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
sns.barplot(data=data1, x="Age", y="Total_EMI_per_month")
plt.xticks(rotation=90)
plt.title("Age vs EMI ")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# We have selcted the barplot becuase it is good for categorical data and  each bar shows the trend clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# Age groups with higher bars are paying more on average mean they either have bigger loans or more loans and bank can target these groups for premium loan products.
#
# Age groups with lower bars are paying smaller EMIs and can either don’t take many loans or have smaller loans and bank might offer them smaller or entry-level loan products

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.
# 1.Postive Business impact
#
# Helps the bank see which age groups are paying more EMIs.
#
# Age groups with higher EMIs and likely stable income can be targeted for bigger or premium loans, increasing profit.
#
# 2.Negative growth insight
#
# Age groups with high EMIs but low income or low credit scores may struggle to pay, increasing loan default risk.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_data = data1.select_dtypes(include=['int64','float64'])
plt.figure(figsize=(12,8))
sns.heatmap(numeric_data.corr(), cmap="coolwarm", annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# We use a correlation heatmap because it shows the relationship between numerical variables in the dataset clearly.
#
# Colors make it easy to identify positive and negative correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# The heatmap shows the relationship between numerical variables in the dataset.
#
# Positive values mean variables increase together.
#
# Negative values mean one increases while the other decreases.
#
# It helps find strongly related features like income and salary.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
cols = ["Annual_Income", "Monthly_Inhand_Salary", "Outstanding_Debt", "Credit_Utilization_Ratio", "Credit_Score"]
sns.pairplot(data1[cols], hue="Credit_Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Shows relationships between multiple variables.
#
# Shows distribution of each variable

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# The pairplot shows the relationship between multiple numerical variables in the dataset.
#
# Customers with higher annual income usually have higher monthly in-hand salary.
#
# There is a relationship between outstanding debt and credit utilization ratio.
#
# Customers with different credit scores show different financial patterns.
#
# The plot helps identify clusters and patterns among Good, Standard, and Poor credit score customers.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
# Monitor customers with high debt and delayed payments to reduce risk.
#
# Identify risky customers early using data analysis.
#
# Give better loan offers to customers with good credit scores.
#
# Encourage customers to make payments on time.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# The analysis shows how income, loans, debt, and payment behavior affect a customer’s credit score. By understanding these factors, the company can identify risky customers, reduce fraud, and make better financial decisions. Data visualization helps understand customer behavior and improve credit management.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
